# %% [markdown]
# # Questions

# %% [markdown]
# synchronisé / non synchronisé ?
#
# plusieurs niveaux de synchronisation ?
#
# un score continu ?

# %% [markdown]
# Les données seront-elles déjà prétraitées ?
#
# filtrage ?
#
# ICA ?
#
# normalisation ?
#
# découpage en époques ?

# %% [markdown]
# Faut-il les calculer à partir d'une mesure de synchronisation ?
#
# Quelle mesure ?
#
# PLV ?
#
# Corrélation ?
#
# Cohérence ?

# %% [markdown]
# À quoi correspond un exemple ?
#
# une dyade complète ?
#
# une époque ?
#
# plusieurs époques ?
